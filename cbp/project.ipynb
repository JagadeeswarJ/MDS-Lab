# %% [markdown]
# # stock price prediction

# %%
# %pip install yfinance
# %pip install pandas
# %pip install sklearn
# %pip install tensorflow

# %%
import yfinance as yf
data = yf.download("AAPL", start="2015-01-01", end="2024-01-01")
# AAPL => Apple Inc
print(data.head())
# Out:
# C:\Users\jagad\AppData\Local\Temp\ipykernel_20836\3843283945.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("AAPL", start="2015-01-01", end="2024-01-01")
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2015-01-02  24.261047  24.729270  23.821672  24.718174  212818400
# 2015-01-05  23.577574  24.110150  23.391173  24.030263  257142000
# 2015-01-06  23.579798  23.839428  23.218089  23.641931  263188400
# 2015-01-07  23.910439  24.010296  23.677436  23.788389  160423600
# 2015-01-08  24.829132  24.886828  24.121249  24.238861  237458000
